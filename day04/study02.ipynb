# %%
# for문

numbers = [1, 2, 3, 4]

for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
# for [변수] in [반복할 대상]:
    반복할_작업

# range(시작, 끝)

for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# 1. 숫자 출력
# for문과 range()를 사용해서 1부터 5까지 출력하세요.
